# %% [markdown]
#     1)Se renseigner sur ce qu’est un KPI
#     2)Importez les bonnes librairies et le dataset resto.csv
#     3)Regardez les 10 premières lignes du dataset
#     4)Quelle est la taille de notre dataset ?
#     5)Affichez toutes les colonnes de notre dataset
#     6)Quel est l’item le plus commandé
#     7)Combien d’items ont été commandés au total chez Chipotle
#     8)Combien de chiffre d’affaire à realisé Chipotle ?
#     9)Quel est le revenu moyen par commande ?

# %%
import seaborn as sns
import pandas
import matplotlib as mat
import numpy
import warnings
warnings.filterwarnings('ignore')

data = pandas.read_csv("../Data/resto.csv")

# %%
data.head(60)
# Out:
#     Unnamed: 0  order_id  quantity                              item_name  \
# 0            0         1         1           Chips and Fresh Tomato Salsa
# 1            1         1         1                                   Izze
# 2            2         1         1                       Nantucket Nectar
# 3            3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4            4         2         2                           Chicken Bowl
# 5            5         3         1                           Chicken Bowl
# 6            6         3         1                          Side of Chips
# 7            7         4         1                          Steak Burrito
# 8            8         4         1                       Steak Soft Tacos
# 9            9         5         1                          Steak Burrito
# 10          10         5         1                    Chips and Guacamole
# 11          11         6         1                   Chicken Crispy Tacos
# ...

# %%
print(data.shape)
#6 colonnes 4622 Lignes
# Out:
# (4622, 6)

# %%
print(data.shape[0])
# Out:
# 4622

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
data.describe()
# Out:
#         Unnamed: 0     order_id     quantity
# count  4622.000000  4622.000000  4622.000000
# mean   2310.500000   927.254868     1.075725
# std    1334.400802   528.890796     0.410186
# min       0.000000     1.000000     1.000000
# 25%    1155.250000   477.250000     1.000000
# 50%    2310.500000   926.000000     1.000000
# 75%    3465.750000  1393.000000     1.000000
# max    4621.000000  1834.000000    15.000000

# %%
sns.catplot(x='item_name', y='quantity', data=data, kind="bar")

# %%
filtered_data = data.loc[(data.quantity > 0) &(data.quantity > 8)]
sns.catplot(x='item_name', y='quantity', data=filtered_data, kind="bar")
#Chips and Fresh Tomato Salsa

# %%
quantite = data.quantity.sum()
print (quantite)
#il y a eu 4972 item commandé
# Out:
# 4972

# %%
data.item_price
# Out:
# 0           NaN
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
for item in data.item_price:
    print(item)
# Out:
# nan
# $3.39
# $3.39
# $2.39
# $16.98
# $10.98
# $1.69
# $11.75
# $9.25
# $9.25
# $4.45
# $8.75
# $8.75
# $11.25
# $4.45
# $2.39
# $8.49
# $8.49
# $2.18
# $8.75
# $4.45
# $8.99
# $3.39
# $10.98
# $3.39
# $2.39
# $8.49
# $8.99
# $1.09
# $8.49
# $2.39
# $8.99
# $1.69
# $8.99
# $1.09
# $8.75
# $8.75
# $4.45
# $2.95
# $11.75
# $2.15
# $4.45
# $11.25
# $11.75
# $8.75
# $10.98
# $8.99
# $3.39
# $8.99
# $3.99
# $8.99
# $2.18
# $10.98
# $1.09
# $8.99
# $2.39
# $9.25
# $11.25
# $11.75
# $2.15
# $4.45
# $9.25
# $11.25
# $8.75
# $8.99
# $8.99
# $3.39
# $8.99
# $10.98
# $8.99
# $1.69
# $8.99
# $3.99
# $8.75
# $4.45
# $8.75
# $8.75
# $2.15
# $8.75
# $11.25
# $2.15
# $9.25
# $8.75
# $8.75
# $9.25
# $8.49
# $8.99
# $1.09
# $9.25
# $2.95
# $11.75
# $11.75
# $9.25
# $11.75
# $4.45
# $9.25
# $4.45
# $11.75
# $8.75
# $8.75
# $4.45
# $8.99
# $8.99
# $3.99
# $8.49
# $3.39
# $8.99
# $1.09
# $9.25
# $4.45
# $8.75
# $2.95
# $4.45
# $2.39
# $8.49
# $8.99
# $8.49
# $1.09
# $8.99
# $3.99
# $8.75
# $9.25
# ...

# %%
i=0
j=0
ca=0

while i < data.shape[0]:
    if i == 0: i += 1
    else :
        plus = data.item_price[i][1:]
        plus_float = pandas.Series(plus, dtype="float")
        ca= ca + (plus_float*data.quantity[i])
        i += 1
        j=j+1
print (ca," ", j)
# Out:
# 0    39234.63
# dtype: float64   4621
