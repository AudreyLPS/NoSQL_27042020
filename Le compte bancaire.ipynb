# %% [markdown]
# Écrire un programme python qui permet de définir une classe CompteBancaire(), qui permette d’instancier des objets tels que compte1, compte2, etc. Le constructeur de cette classe initialisera deux attributs d’instance nom et solde, avec les valeurs par défaut ’Dupont’ et 1000.
#
# Trois autres méthodes seront définies :
#
#     depot(somme) permettra d’ajouter une certaine somme au solde ;
#     retrait(somme) permettra de retirer une certaine somme du solde ;
#     affiche() permettra d’afficher le nom du titulaire et le solde de son compte.

# %%
class CompteBancaire:

	def __init__(self,nom,solde):
		self.nom = nom,
		self.solde = solde

# %%
compte1 = CompteBancaire("Duchmol", 800)

# %%
    def depot(somme):
        print("Changement du solde")
        self._solde  = self._solde + somme
        solde=property(_get_solde, _set_solde)

# %%
    def retrait(somme):
        print("Changement du solde")
        self._solde  = self._solde - somme
        solde=property(_get_solde, _set_solde)

# %%
    def affiche():
        print("Le solde du compte bancaire de", self._nom ," est de", self._solde ,"euros.")

# %%
compte1.depot(350)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-79ad3397419f> in <module>
# ----> 1 compte1.depot(350)
#
# AttributeError: 'CompteBancaire' object has no attribute 'depot'

# %%
compte1.affiche()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-c20cd09dbe1e> in <module>
# ----> 1 compte1.affiche()
#
# AttributeError: 'CompteBancaire' object has no attribute 'affiche'

# %%
compte1 = CompteBancaire("Duchmol", 800)

# %%
compte1.affiche()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-c20cd09dbe1e> in <module>
# ----> 1 compte1.affiche()
#
# AttributeError: 'CompteBancaire' object has no attribute 'affiche'

# %%
compte1.nom
# Out:
# ('Dupont',)

# %%
def _get_nom(self):
        print("Récupération du nom")
        return self._nom

def _set_nom(self, nom):
        print("Changement du nom")
        self._nom  =  nom
        nom=property(_get_nom, _set_nom)

# %%
def _get_solde(self):
        print("Récupération du solde")
        return self._solde

def _set_solde(self, solde):
        print("Changement du solde")
        self._solde  =  solde
        nom=property(_get_solde, _set_solde)

# %%
compte1 = CompteBancaire("Duchmol", 800)

# %%
compte1.nom
# Out:
# ('Duchmol',)

# %%
compte1._get_solde()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-1b6751b3943f> in <module>
# ----> 1 compte1._get_solde()
#
# AttributeError: 'CompteBancaire' object has no attribute '_get_solde'

# %%
compte1.affiche()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-c20cd09dbe1e> in <module>
# ----> 1 compte1.affiche()
#
# AttributeError: 'CompteBancaire' object has no attribute 'affiche'

# %%
class CompteBancaire:
    def affiche(self):
        print("Le solde du compte bancaire de", self._nom ," est de", self._solde ,"euros.")

# %%
compte1.affiche()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-c20cd09dbe1e> in <module>
# ----> 1 compte1.affiche()
#
# AttributeError: 'CompteBancaire' object has no attribute 'affiche'

# %%
compte1.affiche()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-c20cd09dbe1e> in <module>
# ----> 1 compte1.affiche()
#
# AttributeError: 'CompteBancaire' object has no attribute 'affiche'

# %%
class CompteBancaire:

	def __init__(self,nom,solde):
		self.nom = nom
		self.solde = solde
        
	def depot(self,somme):
		print("Changement du solde")
		self._solde  = self.solde + somme
		solde=property(_get_solde, _set_solde)
    
	def retrait(self,somme):
		print("Changement du solde")
		self._solde  = self.solde - somme
		solde=property(_get_solde, _set_solde)
        
	def affiche(self):
		print("Le solde du compte bancaire de", self.nom ," est de", self.solde ,"euros.")

# %%
compte1 = CompteBancaire("Duchmol", 800)

# %%
compte1.affiche()
# Out:
# Le solde du compte bancaire de Duchmol  est de 800 euros.

# %%
compte1.depot(1000)
# Out:
# Changement du solde
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-a5794ec0a7e0> in <module>
# ----> 1 compte1.depot(1000)
#
# <ipython-input-52-7e2f262f6b05> in depot(self, somme)
#       7         def depot(self,somme):
#       8                 print("Changement du solde")
# ----> 9                 self._solde  = self._solde + somme
#      10                 solde=property(_get_solde, _set_solde)
#      11
#
# AttributeError: 'CompteBancaire' object has no attribute '_solde'
